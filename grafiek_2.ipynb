# %% [markdown]
# ### Matplotlib tutorial
#
# Hier heb ik de tutorial Matplotlib Crash Course van freeCodeCamp.org geprobeerd.

# %% [markdown]
# ### Documentatie¶
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html

# %% [markdown]
# ### Load necessary libaries

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,10,0.5)
print(x)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5.  5.5 6.  6.5 7.  7.5 8.  8.5
#  9.  9.5]

# %%
plt.figure(figsize=(18,12))

plt.plot(x,x**2)


plt.xticks(np.arange(0,10,0.5))

plt.show()

# %%
import math

# %%
x = np.arange(0,360.1,0.1)
y = np.sin(np.deg2rad(np.arange(0,360.1,0.1)))

# %%
'''
y = []
for z in x:
    #sin = math.sin(math.radians(z))
    sin = np.sin(np.deg2rad(z))
    y.append(sin)
'''
# Out:
# '\ny = []\nfor z in x:\n    #sin = math.sin(math.radians(z))\n    sin = np.sin(np.deg2rad(z))\n    y.append(sin)\n'

# %%
   
plt.figure(figsize=(18,10),dpi=100)
plt.plot(x,y,label='Sinus')
plt.title('Sinus grafiek\n', fontsize=24)
plt.xlabel('graden', fontsize=24)
plt.grid()
plt.xticks(np.arange(0,370,10))
plt.yticks(np.arange(-1,1.1,0.1))
plt.savefig('mygraph2.png', dpi=300)
plt.legend(fontsize=20)
plt.show()
